# %% [markdown]
# # EDA — Sales Call Copilot Knowledge Base & Call Corpus

# %%
import pandas as pd
kb = pd.read_csv('../data/knowledge_base.csv')
calls = pd.read_csv('../data/call_transcripts.csv')
kb['objection_type'].value_counts()

# %% [markdown]
# ## Win rate: recommended-play vs. improvised

# %%
calls.groupby('used_recommended_play')['won'].mean()
